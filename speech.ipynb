# %%
import os
import re
import json
data_dir='./data/speech'
md_list=os.listdir(data_dir)
print(md_list)
# Out:
# ['[逐字稿] 【KP 國是會議】EP.10：民主化的 AI 科技.md', '[逐字稿] 【KP 國是會議】EP.11：國家的科技發展策略與政策.md', '[逐字稿] 【KP 國是會議】EP.9 智慧教育：打造台灣成為一個學習型國家.md', '[逐字稿] 【KP政策記者會】「聯合政府，團結台灣」終結政治惡鬥、再造美好台灣.md', '[逐字稿] 【民眾之聲_台南開講】擋陸配參政引兩國論 陸委會急緩頰！兩岸現階段「難統難獨」 藍綠３０年吵什麼？.md', '[逐字稿] 【民眾之聲_苗栗開講】在野整合「納入郭董」？柯文哲一句話給答案！.md', '[逐字稿] 【民眾之聲／南投開講】當柯文哲的面問_為何善變_!柯文哲接球_一次講清楚_！.md', '[逐字稿] 【民眾之聲／嘉義開講】受夠了!嘉義民眾超兇提問!柯文哲神回全場掌聲響起！@TPP_Media @Team__KP.md', '[逐字稿] 【民眾之聲／平鎮開講】民眾超激動提問 現場一頭霧水..柯文哲秒懂秒答征服全場！@TPP_Media.md', '[逐字稿] 搶救少子化，讓柯P當你的神隊友！.md', '[逐字稿] 柯文哲 高雄大學超派QA.md', '[逐字稿] 柯文哲專訪 2023年11月7日.md', '[逐字稿] 柯文哲記者聯訪 2023年11月04日.md', '[逐字稿] 柯文哲記者聯訪 2023年11月11日.md', '[逐字稿] 柯文哲記者聯訪 2023年11月12日.md', '[逐字稿] 柯文哲記者聯訪 2023年11月20日.md', '[逐字稿] 柯盈配成軍！2024政黨輪替 這一戰我們會贏.md', '[逐字稿] 讓3？3_3平手怎麼處理？.md', '[逐字稿] 讓年輕人留在家鄉 產業.教育必須連動改革.md', '[逐字稿] 農為國本，五大政見守護台灣農業，再創農村新生命.md', '[逐字稿] 雙方民調誤差範圍內 柯：無論勝負我都禮讓.md', '[逐字稿] 高二生尖銳提問！柯文哲金句連發！在野合作別淪放話比賽！ @TPP_Media.md']

# %%
for file in md_list:
    out=[]
    with open(data_dir+'/'+file) as f:
        title=file[5:-3].strip()
        lines=f.readlines()
        topic=''
        s1=''
        s2=''
        topic=''   
        kp_tag=False
        topic_tag=False 
        for line in lines:
            check_kp=(line.find("#### 柯文哲") != -1)
            check_topic=(line.find("#### ") != -1) and (not line.find("#### tags") != -1) and (not check_kp)
            check_end=(line.find('---')!=-1)
            if(check_topic):
                    topic_tag=True
                    topic=topic+line[5:-1]+':'
                    continue
            
            if(check_kp):
                    kp_tag=True                
                    continue

            if(check_end):
                if(topic_tag):
                    topic_tag=False
                    continue
                else:

                    kp_tag=False
                    topic=''
                    s1=''
                    s2=''
                    continue
                    
            if(topic_tag):
                if(line!='\n'):
                    topic=topic+line

            if(kp_tag):
                if(line!='\n'):
                    tmp=line
                    tmp_list = re.split(r"([。?？])", tmp)
                    #tmp.split('。?')
                    tmp_list.append("")
                    tmp_list = ["".join(i) for i in zip(tmp_list[0::2],tmp_list[1::2])]
                    
                    for sentence in tmp_list:
                        sentence=sentence.strip()
                        if(s1==''):
                            s1=sentence
                        else:
                            s2=sentence
                        if(s2!=''):
                            if(topic==''):
                                topic=title
                            out.append({'topic':topic,'sentence 1':s1,'sentence 2':s2})
                            s1=s2
                    
    file_name=file[:-3].replace('.',' ')
    output_file='./Preprocessed data/speech/'+file_name
    print(output_file)
    with open(output_file, "w") as f:        
        json.dump(out,f,indent=2,ensure_ascii=False)
# Out:
# ./Preprocessed data/speech/[逐字稿] 【KP 國是會議】EP 10：民主化的 AI 科技
# ./Preprocessed data/speech/[逐字稿] 【KP 國是會議】EP 11：國家的科技發展策略與政策
# ./Preprocessed data/speech/[逐字稿] 【KP 國是會議】EP 9 智慧教育：打造台灣成為一個學習型國家
# ./Preprocessed data/speech/[逐字稿] 【KP政策記者會】「聯合政府，團結台灣」終結政治惡鬥、再造美好台灣
# ./Preprocessed data/speech/[逐字稿] 【民眾之聲_台南開講】擋陸配參政引兩國論 陸委會急緩頰！兩岸現階段「難統難獨」 藍綠３０年吵什麼？
# ./Preprocessed data/speech/[逐字稿] 【民眾之聲_苗栗開講】在野整合「納入郭董」？柯文哲一句話給答案！
# ./Preprocessed data/speech/[逐字稿] 【民眾之聲／南投開講】當柯文哲的面問_為何善變_!柯文哲接球_一次講清楚_！
# ./Preprocessed data/speech/[逐字稿] 【民眾之聲／嘉義開講】受夠了!嘉義民眾超兇提問!柯文哲神回全場掌聲響起！@TPP_Media @Team__KP
# ./Preprocessed data/speech/[逐字稿] 【民眾之聲／平鎮開講】民眾超激動提問 現場一頭霧水  柯文哲秒懂秒答征服全場！@TPP_Media
# ./Preprocessed data/speech/[逐字稿] 搶救少子化，讓柯P當你的神隊友！
# ./Preprocessed data/speech/[逐字稿] 柯文哲 高雄大學超派QA
# ./Preprocessed data/speech/[逐字稿] 柯文哲專訪 2023年11月7日
# ./Preprocessed data/speech/[逐字稿] 柯文哲記者聯訪 2023年11月04日
# ./Preprocessed data/speech/[逐字稿] 柯文哲記者聯訪 2023年11月11日
# ./Preprocessed data/speech/[逐字稿] 柯文哲記者聯訪 2023年11月12日
# ./Preprocessed data/speech/[逐字稿] 柯文哲記者聯訪 2023年11月20日
# ./Preprocessed data/speech/[逐字稿] 柯盈配成軍！2024政黨輪替 這一戰我們會贏
# ./Preprocessed data/speech/[逐字稿] 讓3？3_3平手怎麼處理？
# ./Preprocessed data/speech/[逐字稿] 讓年輕人留在家鄉 產業 教育必須連動改革
# ./Preprocessed data/speech/[逐字稿] 農為國本，五大政見守護台灣農業，再創農村新生命
# ./Preprocessed data/speech/[逐字稿] 雙方民調誤差範圍內 柯：無論勝負我都禮讓
# ./Preprocessed data/speech/[逐字稿] 高二生尖銳提問！柯文哲金句連發！在野合作別淪放話比賽！ @TPP_Media
